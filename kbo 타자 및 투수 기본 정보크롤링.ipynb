# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import time

# %%
df1=pd.read_html('https://www.koreabaseball.com/Record/Player/HitterBasic/Basic1.aspx', flavor='html5lib') 
df1=df1[0]
df1
# Out:
#     순위   선수명   팀명    AVG    G   PA   AB    R    H  2B  3B  HR   TB  RBI  SAC  \
# 0    1   김현수   LG  0.362  117  511  453   95  164  39   2  20  267  101    0
# 1    2   양의지   두산  0.358  133  503  439   84  157  29   1  23  257   77    0
# 2    3   이정후   넥센  0.355  109  520  459   81  163  34   2   6  219   57    3
# 3    4   박병호   넥센  0.345  113  488  400   88  138  20   0  43  287  112    0
# 4    5   안치홍  KIA  0.342  130  549  494   88  169  38   1  23  278  118    0
# 5    6   전준우   롯데  0.342  144  614  556  118  190  36   2  33  329   90    1
# 6    7   김주찬  KIA  0.340  121  471  429   71  146  23   0  18  223   93    2
# 7    8   최형우  KIA  0.339  143  609  528   92  179  34   1  25  290  103    0
# 8    9   유한준   KT  0.339  121  480  428   59  145  21   1  20  228   83    2
# 9   10   김재환   두산  0.334  139  602  527  104  176  36   1  44  346  133    0
# 10  11   최주환   두산  0.333  138  590  519   87  173  39   6  26  302  108    0
# ...

# %%
df1.columns
# Out:
# Index(['순위', '선수명', '팀명', 'AVG', 'G', 'PA', 'AB', 'R', 'H', '2B', '3B', 'HR',
#        'TB', 'RBI', 'SAC', 'SF'],
#       dtype='object')

# %%
driverpath =  'C:/Users/driver/chromedriver.exe'
dr = webdriver.Chrome(driverpath)

# %%
dr.get('https://www.koreabaseball.com/Record/Player/HitterBasic/Basic1.aspx' )
dr.find_element_by_id('cphContents_cphContents_cphContents_ucPager_btnNo2').click()

# %%
list = dr.find_elements_by_class_name('record_result')
for data in list:
    df2_table = data.find_element_by_tag_name('table').text
df2_table
# Out:
# '순위 선수명 팀명 AVG G PA AB R H 2B 3B HR TB RBI SAC SF\n31 박용택 LG 0.303 134 583 524 89 159 38 1 15 244 76 0 7\n32 이명기 KIA 0.302 120 502 447 88 135 28 6 4 187 42 11 1\n33 이원석 삼성 0.301 128 543 479 74 144 30 1 20 236 93 0 5\n34 김헌곤 삼성 0.300 141 586 513 77 154 26 2 11 217 71 5 4\n35 박해민 삼성 0.299 144 649 576 114 172 30 10 9 249 68 8 6\n36 송광민 한화 0.297 113 460 434 63 129 24 0 18 207 79 0 4\n37 유강남 LG 0.296 132 465 425 53 126 33 0 19 216 66 2 1\n38 황재균 KT 0.296 142 588 530 76 157 41 3 25 279 88 2 3\n39 이성열 한화 0.295 131 528 485 76 143 21 1 34 268 102 1 2\n40 김선빈 KIA 0.295 127 492 424 73 125 17 2 4 158 49 6 5\n41 신본기 롯데 0.294 139 479 425 55 125 28 1 11 188 71 5 5\n42 이용규 한화 0.293 134 575 491 82 144 14 1 1 163 36 8 5\n43 임병욱 넥센 0.293 134 447 423 76 124 29 3 13 198 60 0 2\n44 강백호 KT 0.290 138 585 527 108 153 32 2 29 276 84 0 3\n45 김하성 넥센 0.288 129 576 511 95 147 27 4 20 242 84 1 5\n46 한동민 SK 0.284 136 562 486 97 138 31 0 41 292 115 0 8\n47 노진혁 NC 0.283 125 458 420 52 119 21 4 11 181 42 1 2\n48 김민성 넥
# ...

# %%
df2_rows = np.array(str(df2_table.split('\n')[1]).split(' ')).reshape(1,16)
df2_rows.shape
# Out:
# (1, 16)

# %%
columns = df1.columns
df2 = pd.DataFrame(columns=columns)
for i in range(1,31):
    df2_rows = np.array(str(df2_table.split('\n')[i]).split(' ')).reshape(1,16)
    df2 = df2.append(pd.DataFrame(df2_rows,columns=columns), ignore_index=True)
df2
# Out:
#     순위   선수명   팀명    AVG    G   PA   AB    R    H  2B  3B  HR   TB  RBI SAC  \
# 0   31   박용택   LG  0.303  134  583  524   89  159  38   1  15  244   76   0
# 1   32   이명기  KIA  0.302  120  502  447   88  135  28   6   4  187   42  11
# 2   33   이원석   삼성  0.301  128  543  479   74  144  30   1  20  236   93   0
# 3   34   김헌곤   삼성  0.300  141  586  513   77  154  26   2  11  217   71   5
# 4   35   박해민   삼성  0.299  144  649  576  114  172  30  10   9  249   68   8
# 5   36   송광민   한화  0.297  113  460  434   63  129  24   0  18  207   79   0
# 6   37   유강남   LG  0.296  132  465  425   53  126  33   0  19  216   66   2
# 7   38   황재균   KT  0.296  142  588  530   76  157  41   3  25  279   88   2
# 8   39   이성열   한화  0.295  131  528  485   76  143  21   1  34  268  102   1
# 9   40   김선빈  KIA  0.295  127  492  424   73  125  17   2   4  158   49   6
# 10  41   신본기   롯데  0.294  139  479  425   55  125  28   1  11  188   71   5
# ...

# %%
dr.get('https://www.koreabaseball.com/Record/Player/HitterBasic/Basic1.aspx' )
dr.find_element_by_id('cphContents_cphContents_cphContents_ucPager_btnNo3').click()

# %%
dr.find_element_by_id('cphContents_cphContents_cphContents_ucPager_btnNo3').click()
list = dr.find_elements_by_class_name('record_result')
for data in list:
    df3_table = data.find_element_by_tag_name('table').text
df3_table
# Out:
# '순위 선수명 팀명 AVG G PA AB R H 2B 3B HR TB RBI SAC SF\n61 김동엽 SK 0.252 124 446 421 58 106 15 0 27 202 76 1 3\n62 최정 SK 0.244 115 489 406 95 99 16 1 35 222 74 0 2'

# %%
columns = df1.columns
df3 = pd.DataFrame(columns=columns)
for i in range(1,3):
    df3_rows = np.array(str(df3_table.split('\n')[i]).split(' ')).reshape(1,16)
    df3 = df3.append(pd.DataFrame(df3_rows,columns=columns), ignore_index=True)
df3
# Out:
#    순위  선수명  팀명    AVG    G   PA   AB   R    H  2B 3B  HR   TB RBI SAC SF
# 0  61  김동엽  SK  0.252  124  446  421  58  106  15  0  27  202  76   1  3
# 1  62   최정  SK  0.244  115  489  406  95   99  16  1  35  222  74   0  2

# %%
batter_basic=pd.concat([df1,df2,df3],ignore_index=True)
batter_basic
# Out:
#     순위   선수명   팀명    AVG    G   PA   AB    R    H  2B  3B  HR   TB  RBI SAC  \
# 0    1   김현수   LG  0.362  117  511  453   95  164  39   2  20  267  101   0
# 1    2   양의지   두산  0.358  133  503  439   84  157  29   1  23  257   77   0
# 2    3   이정후   넥센  0.355  109  520  459   81  163  34   2   6  219   57   3
# 3    4   박병호   넥센  0.345  113  488  400   88  138  20   0  43  287  112   0
# 4    5   안치홍  KIA  0.342  130  549  494   88  169  38   1  23  278  118   0
# 5    6   전준우   롯데  0.342  144  614  556  118  190  36   2  33  329   90   1
# 6    7   김주찬  KIA   0.34  121  471  429   71  146  23   0  18  223   93   2
# 7    8   최형우  KIA  0.339  143  609  528   92  179  34   1  25  290  103   0
# 8    9   유한준   KT  0.339  121  480  428   59  145  21   1  20  228   83   2
# 9   10   김재환   두산  0.334  139  602  527  104  176  36   1  44  346  133   0
# 10  11   최주환   두산  0.333  138  590  519   87  173  39   6  26  302  108   0
# ...

# %%
df1=pd.read_html('https://www.koreabaseball.com/Record/Player/HitterBasic/Basic2.aspx', flavor='html5lib') 
df1=df1[0]
df1
# Out:
#     순위   선수명   팀명    AVG  BB  IBB  HBP   SO  GDP    SLG    OBP    OPS  MH  \
# 0    1   김현수   LG  0.362  47    6    1   61    9  0.589  0.415  1.004  48
# 1    2   양의지   두산  0.358  45    6   13   40   13  0.585  0.427  1.012  48
# 2    3   이정후   넥센  0.355  42    3    8   58    5  0.477  0.412  0.889  46
# 3    4   박병호   넥센  0.345  68   10   17  114    9  0.718  0.457  1.175  46
# 4    5   안치홍  KIA  0.342  36    1   10   57   13  0.563  0.392  0.955  53
# 5    6   전준우   롯데  0.342  48    1    7   82   12  0.592  0.400  0.992  59
# 6    7   김주찬  KIA  0.340  23    5    7   57   15  0.520  0.375  0.895  42
# 7    8   최형우  KIA  0.339  66    7    7   87   17  0.549  0.414  0.963  47
# 8    9   유한준   KT  0.339  47    3    2   53    9  0.533  0.406  0.939  46
# 9   10   김재환   두산  0.334  59    4    9  134    6  0.657  0.405  1.062  51
# 10  11   최주환   두산  0.333  51    1   10   89    5  0.582  0.397  0.979  50
# 11  11   이대호   롯데  0.333  43    7   14   75   18  0.593  0.394  0.987  55
# ...

# %%
df1.columns
# Out:
# Index(['순위', '선수명', '팀명', 'AVG', 'BB', 'IBB', 'HBP', 'SO', 'GDP', 'SLG', 'OBP',
#        'OPS', 'MH', 'RISP', 'PH-BA'],
#       dtype='object')

# %%
driverpath =  'C:/Users/driver/chromedriver.exe'
dr = webdriver.Chrome(driverpath)

# %%
dr.get('https://www.koreabaseball.com/Record/Player/HitterBasic/Basic2.aspx' )
dr.find_element_by_id('cphContents_cphContents_cphContents_ucPager_btnNo2').click()

# %%
list = dr.find_elements_by_class_name('record_result')
for data in list:
    df2_table = data.find_element_by_tag_name('table').text
df2_table
# Out:
# '순위 선수명 팀명 AVG BB IBB HBP SO GDP SLG OBP OPS MH RISP PH-BA\n31 박용택 LG 0.303 47 0 5 107 21 0.466 0.362 0.828 48 0.285 0.667\n32 이명기 KIA 0.302 40 3 3 64 5 0.418 0.363 0.781 41 0.246 0.000\n33 이원석 삼성 0.301 52 1 7 103 10 0.493 0.374 0.867 39 0.302 0.000\n34 김헌곤 삼성 0.300 54 1 10 70 13 0.423 0.375 0.798 46 0.319 0.000\n35 박해민 삼성 0.299 56 0 3 99 9 0.432 0.360 0.792 53 0.339 0.400\n36 송광민 한화 0.297 18 0 4 93 13 0.477 0.328 0.805 36 0.243 0.000\n37 유강남 LG 0.296 28 1 9 80 21 0.508 0.352 0.860 37 0.282 0.214\n38 황재균 KT 0.296 49 1 4 120 5 0.526 0.358 0.884 48 0.252 0.500\n39 이성열 한화 0.295 35 3 5 143 9 0.553 0.347 0.900 34 0.283 0.600\n40 김선빈 KIA 0.295 48 1 9 42 10 0.373 0.374 0.747 33 0.304 0.250\n41 신본기 롯데 0.294 33 2 11 95 12 0.442 0.357 0.799 34 0.300 0.500\n42 이용규 한화 0.293 59 0 12 62 8 0.332 0.379 0.711 44 0.327 0.000\n43 임병욱 넥센 0.293 22 1 0 119 6 0.468 0.327 0.795 31 0.303 0.200\n44 강백호 KT 0.290 52 0 3 124 4 0.524 0.356 0.880 44 0.308 0.300\n45 김하성 넥센 0.288 54 2 5 81 16 0.474 0.358 0.832 43 0.
# ...

# %%
df2_rows = np.array(str(df2_table.split('\n')[1]).split(' ')).reshape(1,15)
df2_rows.shape
# Out:
# (1, 15)

# %%
columns = df1.columns
df2 = pd.DataFrame(columns=columns)
for i in range(1,31):
    df2_rows = np.array(str(df2_table.split('\n')[i]).split(' ')).reshape(1,15)
    df2 = df2.append(pd.DataFrame(df2_rows,columns=columns), ignore_index=True)
df2
# Out:
#     순위   선수명   팀명    AVG  BB IBB HBP   SO GDP    SLG    OBP    OPS  MH   RISP  \
# 0   31   박용택   LG  0.303  47   0   5  107  21  0.466  0.362  0.828  48  0.285
# 1   32   이명기  KIA  0.302  40   3   3   64   5  0.418  0.363  0.781  41  0.246
# 2   33   이원석   삼성  0.301  52   1   7  103  10  0.493  0.374  0.867  39  0.302
# 3   34   김헌곤   삼성  0.300  54   1  10   70  13  0.423  0.375  0.798  46  0.319
# 4   35   박해민   삼성  0.299  56   0   3   99   9  0.432  0.360  0.792  53  0.339
# 5   36   송광민   한화  0.297  18   0   4   93  13  0.477  0.328  0.805  36  0.243
# 6   37   유강남   LG  0.296  28   1   9   80  21  0.508  0.352  0.860  37  0.282
# 7   38   황재균   KT  0.296  49   1   4  120   5  0.526  0.358  0.884  48  0.252
# 8   39   이성열   한화  0.295  35   3   5  143   9  0.553  0.347  0.900  34  0.283
# 9   40   김선빈  KIA  0.295  48   1   9   42  10  0.373  0.374  0.747  33  0.304
# 10  41   신본기   롯데  0.294  33   2  11   95  12  0.442  0.357  0.799  34  0.300
# ...

# %%
dr.get('https://www.koreabaseball.com/Record/Player/HitterBasic/Basic2.aspx' )
dr.find_element_by_id('cphContents_cphContents_cphContents_ucPager_btnNo3').click()

# %%
list = dr.find_elements_by_class_name('record_result')
for data in list:
    df3_table = data.find_element_by_tag_name('table').text
df3_table
# Out:
# '순위 선수명 팀명 AVG BB IBB HBP SO GDP SLG OBP OPS MH RISP PH-BA\n61 김동엽 SK 0.252 17 0 4 108 13 0.480 0.285 0.765 26 0.330 0.286\n62 최정 SK 0.244 58 2 23 129 10 0.547 0.368 0.915 23 0.235 0.000'

# %%
df3_rows = np.array(str(df3_table.split('\n')[1]).split(' ')).reshape(1,15)
df3_rows.shape
# Out:
# (1, 15)

# %%
columns = df1.columns
df3 = pd.DataFrame(columns=columns)
for i in range(1,3):
    df3_rows = np.array(str(df3_table.split('\n')[i]).split(' ')).reshape(1,15)
    df3 = df3.append(pd.DataFrame(df3_rows,columns=columns), ignore_index=True)
df3
# Out:
#    순위  선수명  팀명    AVG  BB IBB HBP   SO GDP    SLG    OBP    OPS  MH   RISP  \
# 0  61  김동엽  SK  0.252  17   0   4  108  13  0.480  0.285  0.765  26  0.330
# 1  62   최정  SK  0.244  58   2  23  129  10  0.547  0.368  0.915  23  0.235
#
#    PH-BA
# 0  0.286
# 1  0.000

# %%
batter_basic2=pd.concat([df1,df2,df3],ignore_index=True)
batter_basic2
# Out:
#     순위   선수명   팀명    AVG  BB IBB HBP   SO GDP    SLG    OBP    OPS  MH   RISP  \
# 0    1   김현수   LG  0.362  47   6   1   61   9  0.589  0.415  1.004  48  0.419
# 1    2   양의지   두산  0.358  45   6  13   40  13  0.585  0.427  1.012  48  0.317
# 2    3   이정후   넥센  0.355  42   3   8   58   5  0.477  0.412  0.889  46   0.37
# 3    4   박병호   넥센  0.345  68  10  17  114   9  0.718  0.457  1.175  46  0.312
# 4    5   안치홍  KIA  0.342  36   1  10   57  13  0.563  0.392  0.955  53  0.403
# 5    6   전준우   롯데  0.342  48   1   7   82  12  0.592    0.4  0.992  59  0.379
# 6    7   김주찬  KIA   0.34  23   5   7   57  15   0.52  0.375  0.895  42  0.361
# 7    8   최형우  KIA  0.339  66   7   7   87  17  0.549  0.414  0.963  47  0.342
# 8    9   유한준   KT  0.339  47   3   2   53   9  0.533  0.406  0.939  46  0.385
# 9   10   김재환   두산  0.334  59   4   9  134   6  0.657  0.405  1.062  51  0.295
# 10  11   최주환   두산  0.333  51   1  10   89   5  0.582  0.397  0.979  50  0.368
# ...

# %%
batter_basic2=batter_basic2.rename(columns={'순위':'순위1','선수명':'선수명1','팀명':'팀명1','AVG':'AVG1'})

# %%
basic_batter=pd.concat([batter_basic,batter_basic2],axis=1)
basic_batter
# Out:
#     순위   선수명   팀명    AVG    G   PA   AB    R    H  2B  ...   IBB HBP   SO GDP  \
# 0    1   김현수   LG  0.362  117  511  453   95  164  39  ...     6   1   61   9
# 1    2   양의지   두산  0.358  133  503  439   84  157  29  ...     6  13   40  13
# 2    3   이정후   넥센  0.355  109  520  459   81  163  34  ...     3   8   58   5
# 3    4   박병호   넥센  0.345  113  488  400   88  138  20  ...    10  17  114   9
# 4    5   안치홍  KIA  0.342  130  549  494   88  169  38  ...     1  10   57  13
# 5    6   전준우   롯데  0.342  144  614  556  118  190  36  ...     1   7   82  12
# 6    7   김주찬  KIA   0.34  121  471  429   71  146  23  ...     5   7   57  15
# 7    8   최형우  KIA  0.339  143  609  528   92  179  34  ...     7   7   87  17
# 8    9   유한준   KT  0.339  121  480  428   59  145  21  ...     3   2   53   9
# 9   10   김재환   두산  0.334  139  602  527  104  176  36  ...     4   9  134   6
# 10  11   최주환   두산  0.333  138  590  519   87  173  39  ...     1  10   89   5
# ...

# %%
basic_batter=basic_batter.drop(['순위','순위1','선수명1','팀명1','AVG1'],axis=1)

# %%
basic_batter.columns
# Out:
# Index(['선수명', '팀명', 'AVG', 'G', 'PA', 'AB', 'R', 'H', '2B', '3B', 'HR', 'TB',
#        'RBI', 'SAC', 'SF', 'BB', 'IBB', 'HBP', 'SO', 'GDP', 'SLG', 'OBP',
#        'OPS', 'MH', 'RISP', 'PH-BA'],
#       dtype='object')

# %%
basic_batter.to_excel('batter_basic.xlsx', encoding='utf-8', index=False)

# %%
pitcher_basic1=pd.read_html('https://www.koreabaseball.com/Record/Player/PitcherBasic/Basic1.aspx', flavor='html5lib') 
pitcher_basic1=pitcher_basic1[0]
pitcher_basic1
# Out:
#     순위   선수명   팀명   ERA   G   W   L  SV  HLD   WPCT       IP    H  HR  BB  \
# 0    1  린드블럼   두산  2.88  26  15   4   0    0  0.789  168 2/3  142  16  38
# 1    2    윌슨   LG  3.07  26   9   4   0    0  0.692      170  158  11  35
# 2    3    소사   LG  3.52  27   9   9   0    0  0.500  181 1/3  192  16  28
# 3    4   이용찬   두산  3.63  25  15   3   0    0  0.833      144  151  14  36
# 4    5  후랭코프   두산  3.74  28  18   3   0    0  0.857  149 1/3  118  12  55
# 5    6   브리검   넥센  3.84  31  11   7   0    1  0.611      199  188  19  50
# 6    7    켈리   SK  4.09  28  12   7   0    0  0.632  158 1/3  152  18  47
# 7    8   양현종  KIA  4.15  29  13  11   0    0  0.542  184 1/3  199  21  43
# 8    9   박종훈   SK  4.18  30  14   8   0    0  0.636  159 1/3  158  16  54
# 9   10   니퍼트   KT  4.25  29   8   8   0    0  0.500  175 2/3  209  26  39
# 10  11  피어밴드   KT  4.30  27   8   8   0    0  0.500  163 1/3  186  24  38
# 11  12   문승원   SK  4.60  31   8   9   1    1  0.471  150 2/3  180  24  37
# ...

# %%
#겹치는 부분 drop할때 중복해서 없애는 걸 방지
pitcher_basic2=pd.read_html('https://www.koreabaseball.com/Record/Player/PitcherBasic/Basic2.aspx', flavor='html5lib') 
pitcher_basic2=pitcher_basic2[0]
pitcher_basic2=pitcher_basic2.rename(columns={'순위':'순위1','선수명':'선수명1','팀명':'팀명1','ERA':'ERA1'})
pitcher_basic2
# Out:
#     순위1  선수명1  팀명1  ERA1  CG  SHO  QS  BSV  TBF    NP    AVG  2B  3B  SAC  SF  \
# 0     1  린드블럼   두산  2.88   0    0  21    0  681  2605  0.226  33   2    5   2
# 1     2    윌슨   LG  3.07   1    1  20    0  689  2632  0.247  23   3    6   3
# 2     3    소사   LG  3.52   1    1  18    0  760  2751  0.267  44   1    2   6
# 3     4   이용찬   두산  3.63   1    0  16    0  608  2237  0.274  24   1    5   7
# 4     5  후랭코프   두산  3.74   0    0  17    0  621  2624  0.220  17   1    5   3
# 5     6   브리검   넥센  3.84   2    1  19    0  829  3089  0.249  28   3    5   1
# 6     7    켈리   SK  4.09   0    0  13    0  674  2497  0.250  28   3    2   4
# 7     8   양현종  KIA  4.15   3    0  17    0  772  2883  0.278  33   0    9   3
# 8     9   박종훈   SK  4.18   0    0  10    0  702  2701  0.254  31   3    3   4
# 9    10   니퍼트   KT  4.25   0    0  20    0  765  2965  0.296  33   4    6   5
# 10   11  피어밴드   KT  4.30   1    0  16    0  707  2723  0.286  27   1   10   3
# ...

# %%
pitcher_basic=pd.concat([pitcher_basic1,pitcher_basic2],axis=1)
pitcher_basic
# Out:
#     순위   선수명   팀명   ERA   G   W   L  SV  HLD   WPCT ...  TBF    NP    AVG  2B  \
# 0    1  린드블럼   두산  2.88  26  15   4   0    0  0.789 ...  681  2605  0.226  33
# 1    2    윌슨   LG  3.07  26   9   4   0    0  0.692 ...  689  2632  0.247  23
# 2    3    소사   LG  3.52  27   9   9   0    0  0.500 ...  760  2751  0.267  44
# 3    4   이용찬   두산  3.63  25  15   3   0    0  0.833 ...  608  2237  0.274  24
# 4    5  후랭코프   두산  3.74  28  18   3   0    0  0.857 ...  621  2624  0.220  17
# 5    6   브리검   넥센  3.84  31  11   7   0    1  0.611 ...  829  3089  0.249  28
# 6    7    켈리   SK  4.09  28  12   7   0    0  0.632 ...  674  2497  0.250  28
# 7    8   양현종  KIA  4.15  29  13  11   0    0  0.542 ...  772  2883  0.278  33
# 8    9   박종훈   SK  4.18  30  14   8   0    0  0.636 ...  702  2701  0.254  31
# 9   10   니퍼트   KT  4.25  29   8   8   0    0  0.500 ...  765  2965  0.296  33
# 10  11  피어밴드   KT  4.30  27   8   8   0    0  0.500 ...  707  2723  0.286  27
# ...

# %%
pitcher_basic=pitcher_basic.drop(['순위','순위1','선수명1','팀명1','ERA1'],axis=1)

# %%
pitcher_basic.columns
# Out:
# Index(['선수명', '팀명', 'ERA', 'G', 'W', 'L', 'SV', 'HLD', 'WPCT', 'IP', 'H', 'HR',
#        'BB', 'HBP', 'SO', 'R', 'ER', 'WHIP', 'CG', 'SHO', 'QS', 'BSV', 'TBF',
#        'NP', 'AVG', '2B', '3B', 'SAC', 'SF', 'IBB', 'WP', 'BK'],
#       dtype='object')

# %%
pitcher_basic.to_excel('pitcher_basic.xlsx', encoding='utf-8', index=False)

# %%
batter_basic=pd.read_csv("batter_basic.csv",encoding="euc-kr")
batter_basic.head

# %%
batter_position=pd.read_csv("batter_position.csv")
batter_position=batter_position.drop(['팀명','순위'],axis=1)
batter_position.head

# %%
# NaN값은 지명타자로 지정
df=pd.merge(batter_basic,batter_position,how='left',on='선수명')
df

# %%
df.replace(np.nan,'지명타자')

# %%
batter_final=df.replace(np.nan,'지명타자')

# %%
batter_final.to_csv('batter_final.csv',encoding='utf-8')
